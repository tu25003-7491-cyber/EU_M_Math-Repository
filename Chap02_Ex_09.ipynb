# %% [markdown]
# <a href="https://colab.research.google.com/github/tu25003-7491-cyber/EU_M_Math-Repository/blob/main/Chap02_Ex_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import Series, DataFrame
import pandas as pd

attri_data1 = {
    'ID': ['1', '2', '3', '4', '5'],
    'Sex': ['F', 'F', 'M', 'M', 'F'],
    'Money': [1000, 2000, 500, 300, 700],
    'Name': ['Saito', 'Horie', 'Kondo', 'Kawada', 'Matsubara']
}

attri_data_frame1 = DataFrame(attri_data1)

attri_data2 = {
    'ID': ['3', '4', '7'],
    'Math': [60, 30, 40],
    'English': [80, 20, 30]
}

attri_data_frame2 = DataFrame(attri_data2)

# データのマージ
merge_data = pd.merge(attri_data_frame1, attri_data_frame2)

# Money, Math, Englishの平均
print(merge_data[['Money', 'Math', 'English']].mean())
# Out:
# Money      400.0
# Math        45.0
# English     50.0
# dtype: float64
