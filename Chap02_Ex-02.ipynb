# %% [markdown]
# <a href="https://colab.research.google.com/github/tu25003-7491-cyber/EU_M_Math-Repository/blob/main/Chap02_Ex-02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy.random as random
import numpy as np

random.seed(0)
rnd_data = random.randn(10)

print(np.min(rnd_data))
print(np.max(rnd_data))
print(np.sum(rnd_data))
# Out:
# -0.977277879876411
# 2.240893199201458
# 7.380231707288347
